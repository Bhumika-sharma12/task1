# %%
import pandas as pd

# %%
df_raw=pd.read_csv("mall_customers_dirty.csv")

# %%
df_raw
# Out:
#     CustomerID           Name  Gender   Age  Annual Income (k$)  \
# 0         1001       John Doe    male  26.0               77.37
# 1         1002   Liam Johnson       F   NaN               75.49
# 2         1003    Alan Walker  FEMALE  27.0               83.44
# 3         1004    Emily Clark       F  42.0                 NaN
# 4         1005            NaN  Female  23.0               90.65
# 5         1006    Sam Collins    Male  28.0               47.14
# 6         1007       John Doe  Female  69.0               48.74
# 7         1008    Emily Clark  Female  33.0               67.73
# 8         1009     Jane Smith    Male  27.0               85.45
# 9         1010       John Doe    Male  52.0               83.80
# 10        1001    Alan Walker       F  58.0               74.73
# 11        1012    Emily Clark    Male  41.0               88.22
# 12        1013   Liam Johnson  Female  48.0               41.56
# 13        1014    Lucas Brown    male  51.0               47.35
# ...

# %% [markdown]
# # Basic Info

# %%
df_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              50 non-null     int64
#  1   Name                    45 non-null     object
#  2   Gender                  50 non-null     object
#  3   Age                     45 non-null     float64
#  4   Annual Income (k$)      48 non-null     float64
#  5   Spending Score (1-100)  46 non-null     float64
#  6   Country                 50 non-null     object
#  7   Joined Date             50 non-null     object
# dtypes: float64(3), int64(1), object(4)
# memory usage: 3.3+ KB

# %%
df_raw.isnull().sum()
# Out:
# CustomerID                0
# Name                      5
# Gender                    0
# Age                       5
# Annual Income (k$)        2
# Spending Score (1-100)    4
# Country                   0
# Joined Date               0
# dtype: int64

# %%
df_raw.shape
# Out:
# (50, 8)

# %%
df_raw.columns
# Out:
# Index(['CustomerID', 'Name', 'Gender', 'Age', 'Annual Income (k$)',
#        'Spending Score (1-100)', 'Country', 'Joined Date'],
#       dtype='object')

# %%
df_raw.dtypes
# Out:
# CustomerID                  int64
# Name                       object
# Gender                     object
# Age                       float64
# Annual Income (k$)        float64
# Spending Score (1-100)    float64
# Country                    object
# Joined Date                object
# dtype: object

# %% [markdown]
# # Step 1 Changing col_names

# %%
df.columns = [col.lower().strip().replace(' ', '_').replace('(', '').replace(')', '').replace('-', '_') for col in df.columns]

# %%
df
# Out:
#     customerid           name gender  age  annual_income_k$  \
# 0         1001       John Doe      M   26             77.37
# 2         1003    Alan Walker      M   27             83.44
# 3         1004    Emily Clark      F   42             63.58
# 5         1006    Sam Collins      M   28             47.14
# 6         1007       John Doe      M   69             48.74
# 7         1008    Emily Clark      M   33             67.73
# 8         1009     Jane Smith      M   27             85.45
# 9         1010       John Doe      M   52             83.80
# 11        1012    Emily Clark      M   41             88.22
# 12        1013   Liam Johnson      M   48             41.56
# 13        1014    Lucas Brown      M   51             47.35
# 15        1016    Emily Clark      M   24             54.80
# 16        1017     Jane Smith      M   52             59.53
# 17        1018   Liam Johnson      M   66             41.64
# 19        1020    Sam Collins      M   55             34.27
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 40 entries, 0 to 48
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   customerid            40 non-null     int64
#  1   name                  40 non-null     object
#  2   gender                40 non-null     object
#  3   age                   40 non-null     int32
#  4   annual_income_k$      40 non-null     float64
#  5   spending_score_1_100  40 non-null     float64
#  6   country               40 non-null     object
# dtypes: float64(2), int32(1), int64(1), object(3)
# memory usage: 2.3+ KB

# %% [markdown]
# # Step 2 Dropping Duplicates

# %%
df=df.drop_duplicates(subset="customerid")

# %% [markdown]
# # Step 3 Dropping null

# %%
df=df.dropna(subset=["name","age"])

# %% [markdown]
# # Step 4 filling null

# %%
mdn=df["annual_income_k$"].median()
mdn
# Out:
# 63.58

# %%
df.loc[:, "annual_income_k$"] = df["annual_income_k$"].fillna(mdn)

# %%
df.loc[:, "spending_score_1_100"] = df["spending_score_1_100"].fillna(mdn)

# %% [markdown]
# # Step 5 replacing Values

# %%
df["gender"]=df["gender"].replace(["male","Male"],"M")

# %%
df["gender"]=df["gender"].replace(["FEMALE","Female"],"F")

# %%
df["country"]=df["country"].replace(["ca","CANADA","Canada"],"Canada")

# %%
df["country"]=df["country"].replace(["united states","united states","us","USA"],"USA")

# %%
df["country"]=df["country"].replace(["united kingdom","uk","UK"],"UK")

# %% [markdown]
# # Step 6 Changing datatypes

# %%
df['age'] = df['age'].astype(int)

# %%
df
# Out:
#     customerid           name gender  age  annual_income_k$  \
# 0         1001       John Doe      M   26             77.37
# 2         1003    Alan Walker      M   27             83.44
# 3         1004    Emily Clark      F   42             63.58
# 5         1006    Sam Collins      M   28             47.14
# 6         1007       John Doe      M   69             48.74
# 7         1008    Emily Clark      M   33             67.73
# 8         1009     Jane Smith      M   27             85.45
# 9         1010       John Doe      M   52             83.80
# 11        1012    Emily Clark      M   41             88.22
# 12        1013   Liam Johnson      M   48             41.56
# 13        1014    Lucas Brown      M   51             47.35
# 15        1016    Emily Clark      M   24             54.80
# 16        1017     Jane Smith      M   52             59.53
# 17        1018   Liam Johnson      M   66             41.64
# 19        1020    Sam Collins      M   55             34.27
# ...

# %%
df.to_csv("mall_customers_clean.csv", index=False)
